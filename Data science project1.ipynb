# %%
import pandas as pd

# %%
df = pd.read_csv('Ecommerce Purchases')
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
#DISPLAY TOP 10 ROWS OF DATASET
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
#DISPLAY LAST 10 ROWS OF DATASET
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
#check datatype of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
#check for null values
df.isnull()
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %%
#hoe many rows and columns are in dataset
# number of rows
len(df.columns)
# Out:
# 14

# %%
len(df)
#total number of rows
# Out:
# 10000

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#higest and lowest purchases price
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df['Purchase Price'].min()
#lowest purchase price
# Out:
# 0.0

# %%
#average purchase price
df['Purchase Price'].mean()
# Out:
# 50.347302

# %%
#how many people have french fr as language
len(df[df['Language'] == 'fr'])
# Out:
# 1097

# %%
#job tittle that contains engineer
len(df[df['Job'].str.contains('engineer',case=False)])
#case is false makes our stringer case insensitive
# Out:
# 984

# %%
df[df['IP Address'] == '132.207.160.22']['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
#how many people purchase during the AM and how many people during the PM 
# for AM 
len(df[df[ 'AM or PM'] == 'AM'])
# Out:
# 4932

# %%
#PM
len(df[df[ 'AM or PM'] == 'PM'])
# Out:
# 5068

# %%
#or use value count
df[ 'AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
#what is the top 5 most popular email providers given our email to be dan@yahoo.com yahoo here has an index of 1
df['Email'].apply(lambda x:x.split('@')[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
#how many people have master card and a purchase above 50
len(df[(df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] > 50)])
# Out:
# 405

# %%
#or using count
df[(df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] > 50)].count()
# Out:
# Address             405
# Lot                 405
# AM or PM            405
# Browser Info        405
# Company             405
# Credit Card         405
# CC Exp Date         405
# CC Security Code    405
# CC Provider         405
# Email               405
# Job                 405
# IP Address          405
# Language            405
# Purchase Price      405
# dtype: int64

# %%
#find the person with the credit card number
df[df['Credit Card'] == 4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
#how many people card will expire in 2020 given our date format to be 02/20
len(df[df['CC Exp Date'].apply(lambda x : x[3:] == '20')])
   # that is usinng slicing to get our date
# Out:
# 988

# %% [markdown]
# ## PROJECT 2

# %%
cf = pd.read_csv('Salaries.csv')
cf
# Out:
# C:\Users\MERCY\AppData\Local\Temp\ipykernel_10860\2059009510.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   cf = pd.read_csv('Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
cf['BasePay'].dtype
# Out:
# dtype('O')

# %%
# to convert not provided columns to np nan
import numpy as np
cf['BasePay'] = cf['BasePay'].replace('Not Provided',np.nan)

# %%
#convert missing value of basepay from string to float
cf['BasePay'] = cf['BasePay'].astype('float')

# %%
#to drop the nan values in basepay
cf.dropna(subset=['BasePay'])
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.0
# ...                                                ...        ...         ...
# ...

# %%
cf
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 14.7+ MB

# %%
#find the shape of dataset ie num of rows and number of columns
cf.shape[0]
# Out:
# 148654

# %%
cf.shape[1]
#num of columns
# Out:
# 13

# %%
#check for null values
cf.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False     True        False     False
# 148651  False         False     False     True        False     False
# 148652  False         False     False     True        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
#drop id column,notes,agency and status column
#drop id column
cf.drop('Id',axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %%
cf.drop(['Notes','Agency','Status'],axis=1)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#get overall statistics of dataframe
cf.describe()
# Out:
#                   Id        BasePay       TotalPay  TotalPayBenefits  \
# count  148654.000000  148045.000000  148654.000000     148654.000000
# mean    74327.500000   66325.448840   74768.321972      93692.554811
# std     42912.857795   42764.635495   50517.005274      62793.533483
# min         1.000000    -166.010000    -618.130000       -618.130000
# 25%     37164.250000   33588.200000   36168.995000      44065.650000
# 50%     74327.500000   65007.450000   71426.610000      92404.090000
# 75%    111490.750000   94691.050000  105839.135000     132876.450000
# max    148654.000000  319275.010000  567595.430000     567595.430000
#
#                 Year  Notes
# count  148654.000000    0.0
# mean     2012.522643    NaN
# std         1.117538    NaN
# min      2011.000000    NaN
# 25%      2012.000000    NaN
# 50%      2013.000000    NaN
# 75%      2014.000000    NaN
# max      2014.000000    NaN

# %%
#find occurrence of the names top 5
cf['EmployeeName'].value_counts().head(5)
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %%
#find number of unique job titles
cf['JobTitle'].nunique()
# Out:
# 2159

# %%
#display all employees name from fire dpt
cf[cf['JobTitle'].str.contains('FIRE DEPARTMENT',case=False)]['EmployeeName']
# Out:
# 4              PATRICK GARDNER
# 6                    ALSON LEE
# 8               MICHAEL MORRIS
# 9           JOANNE HAYES-WHITE
# 10               ARTHUR KENNEY
#                   ...
# 32623             JAMES BARDEN
# 36162       Joanne Hayes-White
# 72926     Joanne M Hayes-White
# 102303          Robert E Evans
# 110535    Joanne M Hayes-White
# Name: EmployeeName, Length: 226, dtype: object

# %%
#total job titles that contains captain
cf[cf['JobTitle'].str.contains('CAPTAIN',case=False)]['EmployeeName']
# Out:
# 1               GARY JIMENEZ
# 2             ALBERT PARDINI
# 11          PATRICIA JACKSON
# 17            SEBASTIAN WONG
# 22             GEORGE GARCIA
#                  ...
# 116604     Gregory L Stewart
# 120867       Michael J Moran
# 122361    Michael V Rolovich
# 126588      Stephen M Tittel
# 132232       Jeanne M Seyler
# Name: EmployeeName, Length: 552, dtype: object

# %%
#max,min and avg of basepay
#max
cf['BasePay'].max()
# Out:
# 319275.01

# %%
#min
cf['BasePay'].min()
# Out:
# -166.01

# %%
#avg
cf['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
#replace Not provided in employee name column to np nan

cf['EmployeeName'] = cf['EmployeeName'].replace('Not provided',np.nan)

# %%
cf
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#drop rows hAving 3 missing values, 1 givws us the rows having missig value
cf.drop(cf[cf.isnull().sum(axis=1)==3].index,axis=0)
# Out:
#             Id        EmployeeName                      JobTitle    BasePay  \
# 36159    36160      Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160    36161        Gregory Suhr               Chief of Police  302578.00
# 36161    36162          Khoa Trinh   Electronic Maintenance Tech  111921.00
# 36162    36163  Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    36164   Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...        ...                 ...                           ...        ...
# 148649  148650       Roy I Tillery                     Custodian       0.00
# 148650  148651                 NaN                  Not provided        NaN
# 148651  148652                 NaN                  Not provided        NaN
# 148652  148653                 NaN                  Not provided        NaN
# 148653  148654           Joe Lopez    Counselor, Log Cabin Ranch       0.00
#
# ...

# %%
#job title albert pardini
cf[cf['EmployeeName'] == 'ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
#how much does albert pardini make including benefit
cf[cf['EmployeeName'] == 'ALBERT PARDINI']['TotalPayBenefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
#name of person having higest base pay
cf[cf['BasePay'].max() == cf['BasePay'] ]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
#name of employee having the lowest pay
cf[cf['BasePay'].min() == cf['BasePay'] ]
# Out:
#           Id    EmployeeName      JobTitle  BasePay OvertimePay OtherPay  \
# 72832  72833  Irwin Sidharta  Junior Clerk  -166.01      249.02      0.0
#
#       Benefits  TotalPay  TotalPayBenefits  Year  Notes         Agency Status
# 72832     6.56     83.01             89.57  2012    NaN  San Francisco    NaN

# %%
#name
cf[cf['BasePay'].min() == cf['BasePay'] ]['EmployeeName']
# Out:
# 72832    Irwin Sidharta
# Name: EmployeeName, dtype: object

# %%
#find avg base pay per yer
cf.groupby('Year').mean('BasePay')['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
#avg pay of all employee per job title
cf.groupby('JobTitle').mean('BasePay')['BasePay']
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %%
#fund the avg basepay of employee having a bob tittle accountant
cf[cf['JobTitle'] == 'ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %%
data = pd.read_csv('adult.csv')
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
#to get number of rows and columns
print('Number of Rows:', data.shape[0])
print('Number of Columns:',data.shape[1])
# Out:
# Number of Rows: 48842
# Number of Columns: 15

# %%
## fetch random samples from the dataset(50%)
data.sample(frac=0.5)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 45154   36           Private  129263       HS-grad                9
# 38467   31           Private  397467       HS-grad                9
# 46535   60       Federal-gov  404023       HS-grad                9
# 19897   26           Private  189590     Bachelors               13
# 19987   22           Private  437994  Some-college               10
# ...    ...               ...     ...           ...              ...
# 21738   34           Private  209808  Some-college               10
# 14421   24       Federal-gov  219262       HS-grad                9
# 25625   34       Federal-gov  198265     Bachelors               13
# 5988    21           Private   35603       HS-grad                9
# 9447    65  Self-emp-not-inc  538099     Bachelors               13
#
#            marital-status       occupation    relationship   race  gender  \
# 45154             Widowed    Other-service   Not-in-family  White  Female
# ...

# %%
#check for is null values in coulumn
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
#check for is null values in row
data.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### DATA CLEANING REPLACE ? NAN

# %%
#to check how many columns have ? 
data.isin(["?"]).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
import numpy as np
data['workclass'] = data['workclass'].replace("?",np.nan)
data['native-country'] = data['native-country'].replace("?",np.nan)
data['occupation'] = data['occupation'].replace("?",np.nan)

# %%
data.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#drop missing values
per_missing = data.isnull().sum()*100/len(data)
per_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
## drop all missing values
data.dropna(how='any',inplace=True)
data.shape
# Out:
# (45222, 15)

# %%
## check for duplicate data and drop them
dup = data.duplicated().any()
dup
# Out:
# True

# %%
## to    drop duplicated
data = data.drop_duplicates()
data.shape
# Out:
# (45175, 15)

# %%
# to check the diff
45222 - 45175
# Out:
# 47

# %%
# get statistics of the dataframe
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# get statistics of the dataframe
data.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
data['educational-num'].unique()
# Out:
# array([ 7,  9, 12, 10,  6, 15,  4, 13, 14,  3, 11,  5, 16,  8,  2,  1],
#       dtype=int64)

# %%
#to drop a column 'educational-num','capital-gain''capital-loss'
data = data.drop(['educational-num','capital-gain', 'capital-loss'],axis=1)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
#whta is the distribution of age column
data['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data['age'].hist()
# Out:
# <Axes: >

# %%
#total num of persons having age form 17 to 48
sum((data['age']>= 17) & (data['age']<= 48))
# Out:
# 34858

# %%
#using between
sum(data['age'].between(17,48))
# Out:
# 34858

# %%
#whta is distribution of workclass
data['workclass'].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
data['workclass'].hist()
#to change our histogram size
plt.figure(figsize=(35,35))

# %%
#how many persons have bachelors or masters degree
sum((data['education'] == 'Bachelors') | (data['education'] == 'Masters'))
# Out:
# 10072

# %%
data['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
#replace slaray values less than 50k with 0 and > 5ok with 1
#create a func
def salary_data(income):
    if income == '<=50K':
        return 0
    else: 
        return 1

# %%
data['data_enconded'] = data['income'].apply(salary_data)

# %%
data.head(5)
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country income  data_enconded
# 0  United-States  <=50K              0
# 1  United-States  <=50K              0
# 2  United-States   >50K              1
# 3  United-States   >50K              1
# ...

# %%
#using replace method
data.replace(to_replace=['<=50K', '>50K'],value=[0,1],inplace=True)

# %%
#which workclass gets the highest salary
#firt gropby workclass
data.groupby('workclass')['income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554407
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Private             0.217816
# Without-pay         0.095238
# Name: income, dtype: float64

# %%
#which gender has the bettter chance to get income greater than 50k#
data.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.312609
# Female    0.113692
# Name: income, dtype: float64

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'data_enconded'],
#       dtype='object')

# %%
#convert workclass dataype to category datatype
data['workclass'].astype('category')
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 45175, dtype: category
# Categories (7, object): ['Federal-gov', 'Local-gov', 'Private', 'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  object
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  int64
#  12  data_enconded   45175 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 4.8+ MB

# %%
titanic_df =  pd.read_csv('Titanic-Dataset.csv')

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#data info
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#statistics of all columns in dataframe
titanic_df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
#check for is null values
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data filtering

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic_df[['Name', 'Sex']]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
sum(titanic_df['Sex'] == 'male')
# Out:
# 577

# %%
sum(titanic_df['Sex'] == 'female')
# Out:
# 314

# %%
#all info about male passenger
titanic_df[titanic_df['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#to check howmany people survived in titanic
sum(titanic_df['Survived'] == 1)
# Out:
# 342

# %%
titanic_df[titanic_df['Survived'] == 1].head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(titanic_df.isnull())
# Out:
# <Axes: >

# %%
#percentage of null  values
per_null = titanic_df.isnull().sum()* 100/len(titanic_df)
per_null
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
#DROP COLUMN
titanic_df.drop('Cabin',axis=1,inplace=True)

# %%
#HANDLE MISSING VALUES
import numpy as np

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
titanic_df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
#to handle missing value in embark
# to check for the most appeared value in 'Embarked' column
titanic_df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
#to fill missing data in 'Embarked' column
titanic_df['Embarked'].fillna('S',inplace=True)

# %%
#to check for missing value
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
#handle missing value for numberical column
#to fill missing data in age column with mean of data in age column
titanic_df['Age'].fillna(titanic_df['Age'].mean(),inplace=True)

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## CATEGORICAL ENCODING

# %%
#categorical encoding for sex and embarked column
titanic_df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic_df['Gender'] = titanic_df['Sex'].map({'male':1,'female':0})

# %%
titanic_df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked  Gender
# 0      0  A/5 21171  7.25        S       1

# %%
#we can use insert method to insert our data in a new posistion
#titanic_df.insert(5pos,gender col name, x variable name)

# %%
titanic_df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
#to encode Embarked coulmn
pd.get_dummies(titanic_df,columns=['Embarked'])
#this create 3 seperate columns of Embarked s q and c
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data1 = pd.get_dummies(titanic_df,columns=['Embarked'],drop_first=True)
#to drop embarked first column that is Embarked_C
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ## UNIVARIANT ANALYSIS

# %%
#univariant analysis that is analysis on 1 column
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
# how many people survived
sum(titanic_df['Survived'] == 1)
# Out:
# 342

# %%
# how many people died
sum(titanic_df['Survived'] == 0)
# Out:
# 549

# %%
#using value count
titanic_df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
import matplotlib.pyplot
import seaborn as sns
sns.countplot(data=titanic_df,x ='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
#how many people were in first class
sum(titanic_df['Pclass'] == 1)
# Out:
# 216

# %%
#how many people were in 2nd class
sum(titanic_df['Pclass'] == 2)
# Out:
# 184

# %%
#how many people were in 3rd class
sum(titanic_df['Pclass'] == 3)
# Out:
# 491

# %%
#number of female and male passenger
#how many people were in first class
sum(titanic_df['Sex'] == 'female')
# Out:
# 314

# %%
#how many people were in first class
sum(titanic_df['Sex'] == 'male')
# Out:
# 577

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
#who has better chances of survival between male and female
sns.barplot(x='Sex',y='Survived',data=titanic_df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
#which passenger class has better chance of survival
sns.barplot(x='Pclass',y='Survived',data=titanic_df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
#to find size of a size of a family
titanic_df['Family_Size']  = titanic_df['SibSp'] + titanic_df['Parch']

# %%
titanic_df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked  Gender  Family_Size
# 0      0  A/5 21171  7.25        S       1            1

# %%
#to find fare person
titanic_df['person_fare'] = titanic_df['Fare']/(titanic_df['Family_Size'] +1 )
#we add 1 to reprensent the person

# %%
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Gender  Family_Size  person_fare
# 0      0         A/5 21171   7.2500        S       1            1      3.62500
# 1      0          PC 17599  71.2833        C       0            1     35.64165
# 2      0  STON/O2. 3101282   7.9250        S       0            0      7.92500
# ...

# %%
app_df = pd.read_csv('googleplaystore.csv')
app_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#find the num of rows and columns
print('Number of Rows',app_df.shape[0])
print('Number of Columns',app_df.shape[1])
# Out:
# Number of Rows 10841
# Number of Columns 13

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
app_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#total number of app titles that contain astrology
app_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
app_df.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#   Reviews Size Installs  Type Price Content Rating        Genres  \
# 0     159  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %%
sum(app_df['App'].str.contains('Astrology'))
# Out:
# 3

# %%
#find avg of app rating
app_df['Rating'].mean()
# Out:
# 4.193338315362443

# %%
#total number of unique columns in category column
app_df['Category'].nunique()
# Out:
# 34

# %%
#the avg rating of each category
app_df.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
#total number of apps having 5 sater rating
app_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
sum(app_df['Rating'] == 5.0)
# Out:
# 274

# %%
#to convert  review column to int we have to remove a column containg 3.om
app_df['Reviews'] = app_df['Reviews'].replace('3.0M',3.0)

# %%
#find the avg value of reviews
#first convert reviews to int
app_df['Reviews'] = app_df['Reviews'].astype('float')

# %%
app_df['Reviews'].mean()
# Out:
# 444111.9265750392

# %%
#total number of free and paid apps
app_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
sum(app_df['Type'] == 'Free')
# Out:
# 10039

# %%
sum(app_df['Type'] == 'Paid')
# Out:
# 800

# %%
#or use value counts
app_df['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
#which app has maximum rewiew
app_df[app_df['Reviews'].max() == app_df['Reviews']]['App']
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
#display 5 apps having highest review
fit = app_df['Reviews'].sort_values(ascending=False).head(5).index
#indexes helps us to retrieve our index

# %%
app_df.loc[fit]['App']
# Out:
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %%
#find  avg rating of free and paid apps
#for free
app_df[app_df['Type'] == 'Free']['Rating'].mean()
# Out:
# 4.186202546163551

# %%
app_df[app_df['Type'] == 'Paid']['Rating'].mean()
# Out:
# 4.26661514683153

# %%
#using groupby
app_df.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
#display top 5 apps having max install
app_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#firt to convert install column to float
#firt remove , seperating the strings
app_df['Installs_1'] = app_df['Installs'].str.replace(',','')

# %%
app_df['Installs_1'] =  app_df['Installs_1'].str.replace('+','')
# Out:
# C:\Users\MERCY\AppData\Local\Temp\ipykernel_10860\92717933.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   app_df['Installs_1'] =  app_df['Installs_1'].str.replace('+','')

# %%
#to replace column containg free to 0
# app_df['Installs_1'] = app_df['Installs_1'].str.replace('Free','0')

# %%
#convert datatype to int
#app_df['Installs_1'] =  app_df['Installs_1'].astype('int')

# %%
app_df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size    Installs  Type Price Content Rating  \
# 0    159.0   19M     10,000+  Free     0       Everyone
# 1    967.0   14M    500,000+  Free     0       Everyone
# 2  87510.0  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver  \
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up
#
#   Installs_1
# 0      10000
# 1     500000
# 2    5000000

# %%
#top five apps having maximum install
idx =app_df['Installs_1'].sort_values(ascending=False).head(5).index

# %%
app_df.loc[idx]['App']
# Out:
# 10472    Life Made WI-Fi Touchscreen Photo Frame
# 1655                            Candy Crush Saga
# 3870                                    Snapchat
# 1759                                Temple Run 2
# 3879                                         Pou
# Name: App, dtype: object

# %%
udemy_df = pd.read_csv('udemy_courses.csv',parse_dates=['published_timestamp'])
udemy_df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %%
udemy_df.describe(include='all')
# Out:
# C:\Users\MERCY\AppData\Local\Temp\ipykernel_10860\2941535788.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   udemy_df.describe(include='all')
#            course_id                   course_title  \
# count   3.678000e+03                           3678
# unique           NaN                           3663
# top              NaN  Acoustic Blues Guitar Lessons
# freq             NaN                              3
# first            NaN                            NaN
# last             NaN                            NaN
# mean    6.759720e+05                            NaN
# std     3.432732e+05                            NaN
# min     8.324000e+03                            NaN
# 25%     4.076925e+05                            NaN
# ...

# %%
udemy_df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
udemy_df.duplicated().sum()
# Out:
# 6

# %%
#to check for duplicate value and drop it
udemy_df = udemy_df.drop_duplicates()

# %%
print('Are there any Duplicate Values in dataset:',udemy_df.duplicated().any())
# Out:
# Are there any Duplicate Values in dataset: False

# %%
##find number of coserses per subject
udemy_df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
udemy_df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
courses = udemy_df['subject'].value_counts()
courses
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data= udemy_df,x = 'subject')

plt.xlabel('Subjects',fontsize=13)
plt.ylabel('Number of courses Per Subject',fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %%
#levels of udemy providing the courses
udemy_df['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sns.countplot(data= udemy_df,x = 'level')

plt.xlabel('level',fontsize=13)
plt.ylabel('Number of courses Per level',fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %%
#display the count of paid and free courses
udemy_df['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
sns.countplot(data= udemy_df,x = 'is_paid')

plt.xlabel('is_paid',fontsize=13)
plt.ylabel('Number of free and paid courses',fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %%
#which course has more lecture free or paid
udemy_df.groupby('is_paid').mean()['num_lectures']
# Out:
# C:\Users\MERCY\AppData\Local\Temp\ipykernel_10860\1275095130.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   udemy_df.groupby('is_paid').mean()['num_lectures']
# is_paid
# False    21.416129
# True     41.866746
# Name: num_lectures, dtype: float64

# %%
#highest number of subscribers free or paid
udemy_df.groupby('is_paid').mean()
# Out:
# C:\Users\MERCY\AppData\Local\Temp\ipykernel_10860\2669493248.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   udemy_df.groupby('is_paid').mean()
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %%
sns.barplot(data=udemy_df,x='is_paid',y='num_subscribers')
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %%
#which level has the number of subscribers
udemy_df.groupby('level').mean()['num_subscribers']
# Out:
# C:\Users\MERCY\AppData\Local\Temp\ipykernel_10860\2180526977.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   udemy_df.groupby('level').mean()['num_subscribers']
# level
# All Levels            3569.761558
# Beginner Level        3195.459779
# Expert Level           865.448276
# Intermediate Level    1762.482185
# Name: num_subscribers, dtype: float64

# %%
sns.barplot(data=udemy_df,x='level',y='num_subscribers')
plt.xticks(rotation=60)
plt.show()

# %%
#most popular course title
udemy_df[udemy_df['num_subscribers'].max() == udemy_df['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
#display 10 most popular courses per number of subscribers
top_10 = udemy_df.sort_values(by='num_subscribers',ascending=False).head(10)

# %%
sns.barplot(data=top_10,x='num_subscribers',y='course_title')
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
#find  course having the highest number of reviews
udemy_df[udemy_df['num_reviews'].max() == udemy_df['num_reviews']]['subject']
# Out:
# 3230    Web Development
# Name: subject, dtype: object

# %%
sns.barplot(data=udemy_df,x='subject',y='num_reviews')
plt.xticks(rotation=60)
plt.show()

# %%
#does price affect number of reviews
plt.figure(figsize=(15,6))
sns.scatterplot(data=udemy_df,x='price',y='num_reviews')
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
#total number of courses related to python
sum(udemy_df['course_title'].str.contains('python',case=False))
# Out:
# 29

# %%
udemy_df['year'] = udemy_df['published_timestamp'].dt.year
# Out:
# C:\Users\MERCY\AppData\Local\Temp\ipykernel_10860\4188136223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   udemy_df['year'] = udemy_df['published_timestamp'].dt.year

# %%
udemy_df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'year'],
#       dtype='object')

# %%
#in which year was the highest number of courses posted
udemy_df[udemy_df['num_lectures'].max() == udemy_df['num_lectures']]['year']
# Out:
# 2707    2013
# Name: year, dtype: int64

# %%
udemy_df.groupby('year')['num_lectures'].max()
# Out:
# year
# 2011    197
# 2012    215
# 2013    779
# 2014    527
# 2015    544
# 2016    536
# 2017    353
# Name: num_lectures, dtype: int64

# %%
sns.countplot(data=udemy_df,x='year')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
#display 10 most popular python courses per num of subscribers
udemy_df[udemy_df['course_title'].str.contains('python',case=False)].sort_values(by='num_subscribers',ascending=False).head()
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# 2528  https://www.udemy.com/learn-django-code-accept...     True     70
# 3200  https://www.udemy.com/python-and-django-full-s...     True    200
# 3507  https://www.udemy.com/web-engineering-with-pyt...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2497            35267          217            53  All Levels
# ...

# %%
#display category wise count of posted  subjectx [yearwise]
udemy_df.groupby('year')['subject'].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: subject, dtype: int64

# %%
rf_data = pd.read_csv('top-5000-youtube-channels.csv')
rf_data
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
#info of df
rf_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
#stats of df
rf_data.describe(include='all')
# Out:
#         Rank Grade Channel name Video Uploads Subscribers   Video views
# count   5000  5000         5000          5000        5000  5.000000e+03
# unique  5000     6         4993          2286        4612           NaN
# top      1st   B+    Thơ Nguyễn            26         --            NaN
# freq       1  2956            2            17         387           NaN
# mean     NaN   NaN          NaN           NaN         NaN  1.071449e+09
# std      NaN   NaN          NaN           NaN         NaN  2.003844e+09
# min      NaN   NaN          NaN           NaN         NaN  7.500000e+01
# 25%      NaN   NaN          NaN           NaN         NaN  1.862329e+08
# 50%      NaN   NaN          NaN           NaN         NaN  4.820548e+08
# 75%      NaN   NaN          NaN           NaN         NaN  1.124368e+09
# max      NaN   NaN          NaN           NaN         NaN  4.754884e+10

# %%
#check for isnull
rf_data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
#replace
