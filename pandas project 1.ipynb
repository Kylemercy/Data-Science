# %% [markdown]
# # working with pandas using Noble Prize dataset

# %% [markdown]
# ***to import the data***

# %%
# first import the pandas libarary
import pandas as pd
import matplotlib as plt

# %%
df1 = pd.read_csv('complete.csv')

# this reads the dataset

# %%
df1.head(10)
#this prints 10 rows
# Out:
#    awardYear           category  \
# 0       2001  Economic Sciences
# 1       1975            Physics
# 2       2004          Chemistry
# 3       1982          Chemistry
# 4       1979            Physics
# 5       2019  Economic Sciences
# 6       2019              Peace
# 7       2009          Chemistry
# 8       2011            Physics
# 9       1939          Chemistry
#
#                                     categoryFullName  sortOrder portion  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...          2     1/3
# 1                         The Nobel Prize in Physics          1     1/3
# 2                       The Nobel Prize in Chemistry          1     1/3
# 3                       The Nobel Prize in Chemistry          1       1
# 4                         The Nobel Prize in Physics          2     1/3
# 5  The Sveriges Riksbank Prize in Economic Scienc...          1     1/3
# 6                              The Nobel Peace Prize          1       1
# ...

# %%
# to check the columns in the dataset
df1.columns
# Out:
# Index(['awardYear', 'category', 'categoryFullName', 'sortOrder', 'portion',
#        'prizeAmount', 'prizeAmountAdjusted', 'dateAwarded', 'prizeStatus',
#        'motivation', 'categoryTopMotivation', 'award_link', 'id', 'name',
#        'knownName', 'givenName', 'familyName', 'fullName', 'penName', 'gender',
#        'laureate_link', 'birth_date', 'birth_city', 'birth_cityNow',
#        'birth_continent', 'birth_country', 'birth_countryNow',
#        'birth_locationString', 'death_date', 'death_city', 'death_cityNow',
#        'death_continent', 'death_country', 'death_countryNow',
#        'death_locationString', 'orgName', 'nativeName', 'acronym',
#        'org_founded_date', 'org_founded_city', 'org_founded_cityNow',
#        'org_founded_continent', 'org_founded_country',
#        'org_founded_countryNow', 'org_founded_locationString', 'ind_or_org',
#        'residence_1', 'residence_2', 'affiliation_1', 'affiliation_2',
#        'affiliation_3', 'affiliation_4'],
# ...

# %%
# to drop unecessary columns
df1.drop([ 'sortOrder', 'award_link', 'id', 'award_link', 'id', 'name',
       'knownName', 'givenName', 'familyName', 'fullName', 'penName', 
       'laureate_link','birth_country','birth_locationString', 'death_date', 'death_city', 'death_cityNow',
       'death_continent', 'death_country', 'death_countryNow',
       'death_locationString', 'orgName', 'nativeName', 'acronym',
       'org_founded_date', 'org_founded_city', 'org_founded_cityNow',
       'org_founded_continent', 'org_founded_country',
       'org_founded_countryNow', 'org_founded_locationString', 'ind_or_org',
       'residence_1', 'residence_2', 'affiliation_1', 'affiliation_2',
       'affiliation_3', 'affiliation_4'],axis=1, inplace= True)

# %%
#to check if the columns has been droped
df1.columns
# Out:
# Index(['awardYear', 'category', 'categoryFullName', 'portion', 'prizeAmount',
#        'prizeAmountAdjusted', 'dateAwarded', 'prizeStatus', 'motivation',
#        'categoryTopMotivation', 'gender', 'birth_date', 'birth_city',
#        'birth_cityNow', 'birth_continent', 'birth_countryNow'],
#       dtype='object')

# %%
# to check the data type of our columns
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   awardYear              950 non-null    int64
#  1   category               950 non-null    object
#  2   categoryFullName       950 non-null    object
#  3   portion                950 non-null    object
#  4   prizeAmount            950 non-null    int64
#  5   prizeAmountAdjusted    950 non-null    int64
#  6   dateAwarded            533 non-null    object
#  7   prizeStatus            950 non-null    object
#  8   motivation             950 non-null    object
#  9   categoryTopMotivation  20 non-null     object
#  10  gender                 923 non-null    object
#  11  birth_date             923 non-null    object
#  12  birth_city             922 non-null    object
#  13  birth_cityNow          922 non-null    object
# ...

# %%
#to check for null values in differnt columns
df1.isnull().sum()
# Out:
# awardYear                  0
# category                   0
# categoryFullName           0
# portion                    0
# prizeAmount                0
# prizeAmountAdjusted        0
# dateAwarded              417
# prizeStatus                0
# motivation                 0
# categoryTopMotivation    930
# gender                    27
# birth_date                27
# birth_city                28
# birth_cityNow             28
# birth_continent           27
# birth_countryNow          27
# dtype: int64

# %%
#to get number of rows and column
df1.shape
# Out:
# (950, 16)

# %%
#to check for uniques values
df1.nunique()
# Out:
# awardYear                116
# category                   6
# categoryFullName           6
# portion                    4
# prizeAmount               98
# prizeAmountAdjusted      114
# dateAwarded              257
# prizeStatus                3
# motivation               664
# categoryTopMotivation      8
# gender                     2
# birth_date               906
# birth_city               626
# birth_cityNow            623
# birth_continent            6
# birth_countryNow          82
# dtype: int64

# %%
# value count of genders column
df1.gender.value_counts()
# Out:
# male      869
# female     54
# Name: gender, dtype: int64

# %%
#to get percentage of both genders
df1.gender.value_counts(normalize=True)
# Out:
# male      0.941495
# female    0.058505
# Name: gender, dtype: float64

# %%
genders = df1.gender.value_counts()

# %%
df1['birth_date']
# Out:
# 0      1943-00-00
# 1      1922-06-19
# 2      1947-10-01
# 3      1926-08-11
# 4      1926-01-29
#           ...
# 945    1908-05-23
# 946    1901-02-28
# 947    1867-11-07
# 948           NaN
# 949           NaN
# Name: birth_date, Length: 950, dtype: object

# %%
df1.tail()
# Out:
#      awardYear   category              categoryFullName portion  prizeAmount  \
# 945       1972    Physics    The Nobel Prize in Physics     1/3       480000
# 946       1954  Chemistry  The Nobel Prize in Chemistry       1       181647
# 947       1911  Chemistry  The Nobel Prize in Chemistry       1       140695
# 948       1981      Peace         The Nobel Peace Prize       1      1000000
# 949       1963      Peace         The Nobel Peace Prize     1/2       265000
#
#      prizeAmountAdjusted dateAwarded prizeStatus  \
# 945              3345725         NaN    received
# 946              2640218         NaN    received
# 947              7327865         NaN    received
# 948              2929688  1981-10-14    received
# 949              2839286  1963-10-10    received
#
#                                             motivation categoryTopMotivation  \
# 945  for their jointly developed theory of supercon...                   NaN
# ...

# %%
#categories
df1['category']
# Out:
# 0      Economic Sciences
# 1                Physics
# 2              Chemistry
# 3              Chemistry
# 4                Physics
#              ...
# 945              Physics
# 946            Chemistry
# 947            Chemistry
# 948                Peace
# 949                Peace
# Name: category, Length: 950, dtype: object

# %%
df1.columns
# Out:
# Index(['awardYear', 'category', 'categoryFullName', 'portion', 'prizeAmount',
#        'prizeAmountAdjusted', 'dateAwarded', 'prizeStatus', 'motivation',
#        'categoryTopMotivation', 'gender', 'birth_date', 'birth_city',
#        'birth_cityNow', 'birth_continent', 'birth_countryNow'],
#       dtype='object')

# %%
prize_money = (df1['prizeAmount']  >= 100000)

# %%
df1.loc[prize_money]
# Out:
#      awardYear           category  \
# 0         2001  Economic Sciences
# 1         1975            Physics
# 2         2004          Chemistry
# 3         1982          Chemistry
# 4         1979            Physics
# ..         ...                ...
# 945       1972            Physics
# 946       1954          Chemistry
# 947       1911          Chemistry
# 948       1981              Peace
# 949       1963              Peace
#
#                                       categoryFullName portion  prizeAmount  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...     1/3     10000000
# 1                           The Nobel Prize in Physics     1/3       630000
# 2                         The Nobel Prize in Chemistry     1/3     10000000
# 3                         The Nobel Prize in Chemistry       1      1150000
# 4                           The Nobel Prize in Physics     1/3       800000
# ..                                                 ...     ...          ...
# ...

# %%
# droping a column
df1.drop('categoryTopMotivation',axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['awardYear', 'category', 'categoryFullName', 'portion', 'prizeAmount',
#        'prizeAmountAdjusted', 'dateAwarded', 'prizeStatus', 'motivation',
#        'gender', 'birth_date', 'birth_city', 'birth_cityNow',
#        'birth_continent', 'birth_countryNow'],
#       dtype='object')

# %%
df1.loc[prize_money,['awardYear', 'category', 'categoryFullName', 'portion', 'prizeAmount',
       'prizeAmountAdjusted', 'dateAwarded', 'prizeStatus', 'motivation',
       'gender', 'birth_date']].head(20)
# Out:
#     awardYear                category  \
# 0        2001       Economic Sciences
# 1        1975                 Physics
# 2        2004               Chemistry
# 3        1982               Chemistry
# 4        1979                 Physics
# 5        2019       Economic Sciences
# 6        2019                   Peace
# 7        2009               Chemistry
# 8        2011                 Physics
# 9        1939               Chemistry
# 10       1905               Chemistry
# 11       1928               Chemistry
# 12       1980                   Peace
# 13       1999               Chemistry
# 14       2010               Chemistry
# 15       2019               Chemistry
# 16       2007                   Peace
# 17       2000               Chemistry
# 18       1963  Physiology or Medicine
# 19       2000               Chemistry
#
#                                      categoryFullName portion  prizeAmount  \
# ...

# %%
# birth country of nobel laurette
df1['birth_countryNow'].head(50)
# Out:
# 0                USA
# 1            Denmark
# 2             Israel
# 3          Lithuania
# 4           Pakistan
# 5              India
# 6           Ethiopia
# 7             Israel
# 8                USA
# 9            Germany
# 10           Germany
# 11           Germany
# 12         Argentina
# 13             Egypt
# 14             Japan
# 15             Japan
# 16               USA
# 17               USA
# 18    United Kingdom
# 19       New Zealand
# 20            Poland
# 21           Algeria
# 22           Belgium
# 23           Germany
# 24            France
# 25       Switzerland
# 26          Zimbabwe
# 27            France
# 28           Hungary
# 29           Germany
# 30         Australia
# 31            Russia
# 32            Russia
# 33            France
# 34            Mexico
# 35               USA
# 36           Austria
# 37               USA
# 38            France
# 39            France
# 40            Canada
# 41      South Africa
# 42            Sweden
# ...

# %%
countries = ['South Africa','USA','Austria','India',' Russia','Germany',' Australia',' Australia','Canada','United Kingdom',' France',
             'Mexico','China','Israel','Japan','Poland']
filt = df1['birth_countryNow'].isin(countries)

# %%
df1[filt]
# Out:
#      awardYear                category  \
# 0         2001       Economic Sciences
# 2         2004               Chemistry
# 5         2019       Economic Sciences
# 7         2009               Chemistry
# 8         2011                 Physics
# ..         ...                     ...
# 939       2016  Physiology or Medicine
# 943       1980               Chemistry
# 945       1972                 Physics
# 946       1954               Chemistry
# 947       1911               Chemistry
#
#                                       categoryFullName portion  prizeAmount  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...     1/3     10000000
# 2                         The Nobel Prize in Chemistry     1/3     10000000
# 5    The Sveriges Riksbank Prize in Economic Scienc...     1/3      9000000
# 7                         The Nobel Prize in Chemistry     1/3     10000000
# 8                           The Nobel Prize in Physics     1/4     10000000
# ...

# %%
filt1 =df1['category'].str.contains('Chemistry',na=False)
df1[filt1]
# Out:
#      awardYear   category              categoryFullName portion  prizeAmount  \
# 2         2004  Chemistry  The Nobel Prize in Chemistry     1/3     10000000
# 3         1982  Chemistry  The Nobel Prize in Chemistry       1      1150000
# 7         2009  Chemistry  The Nobel Prize in Chemistry     1/3     10000000
# 9         1939  Chemistry  The Nobel Prize in Chemistry     1/2       148822
# 10        1905  Chemistry  The Nobel Prize in Chemistry       1       138089
# ..         ...        ...                           ...     ...          ...
# 940       1986  Chemistry  The Nobel Prize in Chemistry     1/3      2000000
# 941       2005  Chemistry  The Nobel Prize in Chemistry     1/3     10000000
# 943       1980  Chemistry  The Nobel Prize in Chemistry     1/4       880000
# 946       1954  Chemistry  The Nobel Prize in Chemistry       1       181647
# 947       1911  Chemistry  The Nobel Prize in Chemistry       1       140695
#
# ...

# %%
df1[filt1].value_counts().sum()
# Out:
# 104

# %%
#to rename a column
df1.rename(columns={'birth_countryNow':'country'},inplace=True)

# %%
df1['country']
# Out:
# 0            USA
# 1        Denmark
# 2         Israel
# 3      Lithuania
# 4       Pakistan
#          ...
# 945          USA
# 946          USA
# 947       Poland
# 948          NaN
# 949          NaN
# Name: country, Length: 950, dtype: object

# %%
#to obtain the 10 highest pize money won
df1.nlargest(10,'prizeAmount')
# Out:
#     awardYear                category  \
# 0        2001       Economic Sciences
# 2        2004               Chemistry
# 7        2009               Chemistry
# 8        2011                 Physics
# 14       2010               Chemistry
# 16       2007                   Peace
# 24       2007                 Physics
# 32       2003                 Physics
# 51       2010                 Physics
# 57       2006  Physiology or Medicine
#
#                                      categoryFullName portion  prizeAmount  \
# 0   The Sveriges Riksbank Prize in Economic Scienc...     1/3     10000000
# 2                        The Nobel Prize in Chemistry     1/3     10000000
# 7                        The Nobel Prize in Chemistry     1/3     10000000
# 8                          The Nobel Prize in Physics     1/4     10000000
# 14                       The Nobel Prize in Chemistry     1/3     10000000
# 16                              The Nobel Peace Prize     1/2     10000000
# ...

# %%
# to group our data base on continent 
df1['birth_continent'].value_counts()
# Out:
# Europe           494
# North America    304
# Asia              72
# Africa            27
# Oceania           15
# South America     11
# Name: birth_continent, dtype: int64

# %%
df1['birth_continent'].value_counts(normalize=True)
# Out:
# Europe           0.535211
# North America    0.329361
# Asia             0.078007
# Africa           0.029252
# Oceania          0.016251
# South America    0.011918
# Name: birth_continent, dtype: float64

# %%
continent_grp = df1.groupby(['birth_continent'])

# %%
continent_grp.get_group('Asia')
# Out:
#      awardYear                category  \
# 2         2004               Chemistry
# 4         1979                 Physics
# 5         2019       Economic Sciences
# 7         2009               Chemistry
# 14        2010               Chemistry
# ..         ...                     ...
# 936       1968              Literature
# 937       1994                   Peace
# 938       2008                 Physics
# 939       2016  Physiology or Medicine
# 940       1986               Chemistry
#
#                                       categoryFullName portion  prizeAmount  \
# 2                         The Nobel Prize in Chemistry     1/3     10000000
# 4                           The Nobel Prize in Physics     1/3       800000
# 5    The Sveriges Riksbank Prize in Economic Scienc...     1/3      9000000
# 7                         The Nobel Prize in Chemistry     1/3     10000000
# 14                        The Nobel Prize in Chemistry     1/3     10000000
# ...

# %%
continent_grp['country'].value_counts().head(50)
# Out:
# birth_continent  country
# Africa           South Africa                         9
#                  Egypt                                6
#                  Algeria                              2
#                  Liberia                              2
#                  Democratic Republic of the Congo     1
#                  Ethiopia                             1
#                  Ghana                                1
#                  Kenya                                1
#                  Madagascar                           1
#                  Morocco                              1
#                  Nigeria                              1
#                  Zimbabwe                             1
# Asia             Japan                               27
#                  China                               12
#                  India                                9
#                  Israel                               6
# ...

# %%
#value count of europe in each category
continent_grp['category'].value_counts().loc['Europe']
# Out:
# category
# Physics                   114
# Physiology or Medicine    114
# Chemistry                 103
# Literature                 80
# Peace                      53
# Economic Sciences          30
# Name: category, dtype: int64

# %%
plot = continent_grp.plot(kind='hist',title = 'continent')

# %%
continent_grp['gender'].value_counts().loc['Europe']
# Out:
# gender
# male      470
# female     24
# Name: gender, dtype: int64

# %%
#grouping by category
cat_grp = df1.groupby('category')

# %%
cat_grp['gender'].value_counts()
#to check gender with highest win in each  category
# Out:
# category                gender
# Chemistry               male      179
#                         female      5
# Economic Sciences       male       82
#                         female      2
# Literature              male      101
#                         female     15
# Peace                   male       90
#                         female     17
# Physics                 male      210
#                         female      3
# Physiology or Medicine  male      207
#                         female     12
# Name: gender, dtype: int64

# %%
cat_grp['prizeAmount'].nlargest()
#largest prizeamount in each category
# Out:
# category
# Chemistry               2      10000000
#                         7      10000000
#                         14     10000000
#                         80     10000000
#                         86     10000000
# Economic Sciences       0      10000000
#                         139    10000000
#                         140    10000000
#                         145    10000000
#                         152    10000000
# Literature              177    10000000
#                         201    10000000
#                         345    10000000
#                         373    10000000
#                         385    10000000
# Peace                   16     10000000
#                         82     10000000
#                         209    10000000
#                         320    10000000
#                         387    10000000
# Physics                 8      10000000
#                         24     10000000
#                         32     10000000
# ...

# %%
cat_grp['prizeAmount'].nsmallest()
#largest smallest in each category
# Out:
# category
# Chemistry               274    114935
#                         848    116960
#                         726    118165
#                         75     121333
#                         419    121524
# Economic Sciences       432    375000
#                         700    375000
#                         657    400000
#                         800    450000
#                         476    480000
# Literature              910    114935
#                         929    116719
#                         321    116960
#                         286    118165
#                         277    121333
# Peace                   65     116960
#                         329    116960
#                         126    118165
#                         806    118165
#                         146    121333
# Physics                 730    114935
#                         564    116719
#                         436    116960
#                         328    118165
# ...

# %%
cat_grp['prizeAmount'].agg(['mean','median'])
# Out:
#                                 mean     median
# category
# Chemistry               3.629279e+06   800000.0
# Economic Sciences       6.105845e+06  7550000.0
# Literature              2.493811e+06   269000.0
# Peace                   3.124879e+06   480000.0
# Physics                 3.407939e+06   700000.0
# Physiology or Medicine  3.072973e+06   510000.0

# %%
continent_grp['prizeAmount'].agg(['mean','median'])
# Out:
#                          mean     median
# birth_continent
# Africa           5.783342e+06  7000000.0
# Asia             6.179322e+06  8000000.0
# Europe           2.287497e+06   265000.0
# North America    4.492116e+06  3000000.0
# Oceania          4.217438e+06   630000.0
# South America    2.151208e+06   880000.0

# %%
filt = (df1['dateAwarded'] >= '1975-10-17') & (df1['dateAwarded'] <= '2001-01-01')

# %%
df1.loc[filt]
# Out:
#      awardYear   category              categoryFullName portion  prizeAmount  \
# 1         1975    Physics    The Nobel Prize in Physics     1/3       630000
# 3         1982  Chemistry  The Nobel Prize in Chemistry       1      1150000
# 4         1979    Physics    The Nobel Prize in Physics     1/3       800000
# 12        1980      Peace         The Nobel Peace Prize       1       880000
# 13        1999  Chemistry  The Nobel Prize in Chemistry       1      7900000
# ..         ...        ...                           ...     ...          ...
# 937       1994      Peace         The Nobel Peace Prize     1/3      7000000
# 940       1986  Chemistry  The Nobel Prize in Chemistry     1/3      2000000
# 942       2000    Physics    The Nobel Prize in Physics     1/4      9000000
# 943       1980  Chemistry  The Nobel Prize in Chemistry     1/4       880000
# 948       1981      Peace         The Nobel Peace Prize       1      1000000
#
# ...

# %%
country_respondent = df1['country'].value_counts()
country_respondent
# Out:
# USA               274
# United Kingdom     87
# Germany            82
# France             56
# Sweden             29
#                  ...
# Venezuela           1
# Myanmar             1
# Zimbabwe            1
# Ethiopia            1
# Taiwan              1
# Name: country, Length: 82, dtype: int64

# %%
cat_grp['country'].value_counts()
#in each category country with hihest number of wins
# Out:
# category                country
# Chemistry               USA               54
#                         Germany           26
#                         United Kingdom    24
#                         France             9
#                         Japan              7
#                                           ..
# Physiology or Medicine  Luxembourg         1
#                         New Zealand        1
#                         Portugal           1
#                         Romania            1
#                         Venezuela          1
# Name: country, Length: 219, dtype: int64
